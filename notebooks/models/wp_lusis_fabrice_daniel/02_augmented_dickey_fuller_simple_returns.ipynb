# %% [markdown]
# # Prepare Data files.
# - Use returns instead.

# %%
# %load_ext dotenv
# %reload_ext dotenv
# %dotenv

# %% [markdown]
# ### prepare data directory.

# %%
from gw2ml.data.s3_sync import download_folder_from_s3
import pandas as pd
import os

workdir_raw = os.path.join(os.getenv('DATA_PATH'), 'workdir_lusis', 'raw')
workdir_modified = os.path.join(os.getenv('DATA_PATH'), 'workdir_lusis', 'modified')

os.makedirs(workdir_raw, exist_ok=True)
os.makedirs(workdir_modified, exist_ok=True)

download_folder_from_s3(s3_folder_prefix='datasources/gw2/raw/1764510842', local_folder=os.path.join(workdir_raw, 'data'))
# Out:
# Source: ost-s3/datasources/gw2/raw/1764510842
# Target: /models/data/workdir_lusis/raw
#
# Found 280 files to download
#
# ✓ +1 Agony Infusion.csv
# ✓ Aetherkey Piece.csv
# ✓ Ancient Bone.csv
# ✓ Ancient Wood Log.csv
# ✓ Ancient Wood Plank.csv
# ✓ Antique Summoning Stone.csv
# ✓ Armored Scale.csv
# ✓ Asparagus Spear.csv
# ✓ Auric Sliver.csv
# ✓ Bag of Alchemical Materials.csv
# ✓ Bag of Coffee Beans.csv
# ✓ Bag of Flour.csv
# ✓ Bag of Starch.csv
# ✓ Bag of Stolen Goods.csv
# ✓ Bag of Sugar.csv
# ✓ Bay Leaf.csv
# ✓ Beet.csv
# ✓ Black Lion Chest.csv
# ✓ Black Peppercorn.csv
# ✓ Blackberry.csv
# ✓ Blueberry.csv
# ✓ Bolt of Cotton.csv
# ✓ Bolt of Gossamer.csv
# ✓ Bolt of Jute.csv
# ✓ Bolt of Silk.csv
# ✓ Bolt of Wool.csv
# ✓ Bone Chip.csv
# ✓ Bone Shard.csv
# ✓ Bottle of Soy Sauce.csv
# ✓ Bottle of Vintage Wine.csv
# ✓ Bowl of Candy Corn Custard.csv
# ✓ Bowl of Chocolate Frosting.csv
# ✓ Bowl of Coleslaw.csv
# ✓ Bowl of Fancy Bean Chili.csv
# ✓ Bronze Ingot.csv
# ✓ Candy Corn Cookie.csv
# ✓ Carrot.csv
# ✓ Cassava Root.csv
# ✓ Cayenne Pepper.csv
# ✓ Charged Shard.csv
# ✓ Chatoyant Elixir.csv
# ✓ Chili Pepper.csv
# ✓ Chocolate Bar.csv
# ✓ Chocolate Cake.csv
# ✓ Chocolate Chip Cookie.csv
# ✓ Chocolate Orange.csv
# ✓ Choir Bell.csv
# ✓ Choya Spine.csv
# ✓ Cinnamon Stick.csv
# ✓ Clam.csv
# ✓ Clove.csv
# ✓ Coarse Leather Section.csv
# ✓ Coastal Lumber Core.csv
# ✓ Congealed Putrescence.csv
# ✓ Copper Ore.csv
# ✓ Corrupted Core.csv
# ✓ Corrupted Fragment.csv
# ✓ Cup of Potato Fries.csv
# ✓ Cup of Spiced Apple Cider.csv
# ✓ Cured Coarse Leather Square.csv
# ✓ Cured Hardened Leather Square.csv
# ✓ Cured Thick Leather Square.csv
# ✓ Cured Thin Leather Square.csv
# ✓ Delicate Snowflake.csv
# ✓ Delicious Rice Ball.csv
# ✓ Desert Rose Skin.csv
# ✓ Destroyer Core.csv
# ✓ Dragon Ball Champion's Divine Lucky Envelope.csv
# ✓ Dragon Coffer.csv
# ✓ Dragonfish Candy.csv
# ✓ Draught of Hunter's Ale.csv
# ✓ Egg.csv
# ✓ Elder Wood Log.csv
# ✓ Elder Wood Plank.csv
# ✓ Energy Crystal.csv
# ✓ Evergreen Sliver.csv
# ✓ Eye of Kormir.csv
# ✓ Fabulous Fish Fillet.csv
# ✓ Festive Golem Tonic.csv
# ✓ Festive Transom.csv
# ✓ Fine Fish Fillet.csv
# ✓ Flame Ram Blueprints.csv
# ✓ Flavorful Fish Fillet.csv
# ✓ Flawless Snowflake.csv
# ✓ Flax Fiber.csv
# ✓ Fractal Encryption.csv
# ✓ Fried Golden Dumpling.csv
# ✓ Ghost Pepper.csv
# ✓ Ginger Pear Tart.csv
# ✓ Glass of Buttered Spirits.csv
# ✓ Glazed Peach Tart.csv
# ✓ Glittering Snowflake.csv
# ✓ Glob of Ectoplasm.csv
# ✓ Gold Ingot.csv
# ✓ Gold Ore.csv
# ✓ Gossamer Scrap.csv
# ✓ Grape.csv
# ✓ Green Wood Log.csv
# ✓ Green Wood Plank.csv
# ✓ Guild Arrow Cart Blueprints.csv
# ✓ Handful of Red Lentils.csv
# ✓ Hard Wood Log.csv
# ✓ Hardened Leather Section.csv
# ✓ Head of Garlic.csv
# ✓ Head of Lettuce.csv
# ✓ Heavy Bone.csv
# ✓ Heavy Icy Bag.csv
# ✓ Heavy Loot Bag.csv
# ✓ Heavy Moldy Bag.csv
# ✓ Intricate Totem.csv
# ✓ Iron Ingot.csv
# ✓ Iron Ore.csv
# ✓ Jade Runestone.csv
# ✓ Jar of Vegetable Oil.csv
# ✓ Jar of Vinegar.csv
# ✓ Jug of Friesson's Ale.csv
# ✓ Jug of Water.csv
# ✓ Jute Scrap.csv
# ✓ Kralkachocolate Bar.csv
# ✓ Large Bone.csv
# ✓ Large Claw.csv
# ✓ Large Fang.csv
# ✓ Large Scale.csv
# ✓ Ley-Infused Sand.csv
# ✓ Light of Deldrimor Plate—Top Half.csv
# ✓ Linen Scrap.csv
# ✓ Loaf of Rosemary Bread.csv
# ✓ Lotus Root.csv
# ✓ Lucent Mote.csv
# ✓ Lucky Draketail.csv
# ✓ Lucky Guild Firework.csv
# ✓ Lucky New Year Firework.csv
# ✓ Lucky Prismatic Rocket.csv
# ✓ Lump of Coal.csv
# ✓ Lump of Primordium.csv
# ✓ Lump of Raw Ambrite.csv
# ✓ Memory of Battle.csv
# ✓ Miner's Sack.csv
# ✓ Mini Professor Mew.csv
# ✓ Minor Rune of Snowfall.csv
# ✓ Mint Leaf.csv
# ✓ Mithril Ingot.csv
# ✓ Mithril Ore.csv
# ✓ Mushroom.csv
# ✓ Mussel.csv
# ✓ Mystic Coin.csv
# ✓ Omnomberry.csv
# ✓ Onion.csv
# ✓ Orange.csv
# ✓ Oregano Leaf.csv
# ✓ Orichalcum Ingot.csv
# ✓ Orichalcum Ore.csv
# ✓ Oyster.csv
# ✓ Packet of Baking Powder.csv
# ✓ Packet of Salt.csv
# ✓ Passion Fruit.csv
# ✓ Peppermint Oil.csv
# ✓ Piece of Ambrite.csv
# ✓ Piece of Candy Corn Almond Brittle.csv
# ✓ Piece of Candy Corn.csv
# ✓ Piece of Common Unidentified Gear.csv
# ✓ Piece of Rare Unidentified Gear.csv
# ✓ Piece of Unidentified Gear.csv
# ✓ Piece of Zhaitaffy.csv
# ✓ Pile of Allspice Berries.csv
# ✓ Pile of Ascalonian Herbs.csv
# ✓ Pile of Cinnamon and Sugar.csv
# ✓ Pile of Coarse Sand.csv
# ✓ Pile of Crystalline Dust.csv
# ✓ Pile of Flax Seeds.csv
# ✓ Pile of Glittering Dust.csv
# ✓ Pile of Incandescent Dust.csv
# ✓ Pile of Lucent Crystal.csv
# ✓ Pile of Luminous Dust.csv
# ✓ Pile of Putrid Essence.csv
# ✓ Pile of Radiant Dust.csv
# ✓ Pile of Shimmering Dust.csv
# ✓ Pile of Soybeans.csv
# ✓ Pile of Vile Essence.csv
# ✓ Plate of Citrus Clove Meat.csv
# ✓ Plate of Citrus Poultry with Almonds.csv
# ✓ Plate of Steak and Asparagus.csv
# ✓ Platinum Ore.csv
# ✓ Potato.csv
# ✓ Potent Potion of Sons of Svanir Slaying.csv
# ✓ Potent Venom Sac.csv
# ✓ Pouch of Black Pigment.csv
# ✓ Pouch of Blue Pigment.csv
# ✓ Pouch of Brown Pigment.csv
# ✓ Pouch of Orange Pigment.csv
# ✓ Pouch of White Pigment.csv
# ✓ Powdered Rose Quartz.csv
# ✓ Powerful Potion of Slaying Scarlet's Armies.csv
# ✓ Pristine Feather.csv
# ✓ Pulsing Brandspark.csv
# ✓ Quartz Crystal.csv
# ✓ Raspberry Peach Compote.csv
# ✓ Raspberry.csv
# ✓ Rawhide Leather Section.csv
# ✓ Reindeer Tonic.csv
# ✓ Roasted Artichoke.csv
# ✓ Rosemary Sprig.csv
# ✓ Rotted Titan Amber.csv
# ✓ Rugged Leather Section.csv
# ✓ Rutabaga.csv
# ✓ Saffron Thread.csv
# ✓ Sage Leaf.csv
# ✓ Salvageable Hide.csv
# ✓ Scale.csv
# ✓ Scoop of Mintberry Swirl Ice Cream.csv
# ✓ Sealed Package of Snowballs.csv
# ✓ Seasoned Wood Log.csv
# ✓ Sesame Seed.csv
# ✓ Shard of Glory.csv
# ✓ Silk Scrap.csv
# ✓ Silver Ingot.csv
# ✓ Silver Ore.csv
# ✓ Slab of Poultry Meat.csv
# ✓ Slab of Red Meat.csv
# ✓ Small Claw.csv
# ✓ Small Fang.csv
# ✓ Small Scale.csv
# ✓ Small Totem.csv
# ✓ Small Venom Sac.csv
# ✓ Small Wintersday Gift.csv
# ✓ Snow Truffle.csv
# ✓ Snowflake.csv
# ✓ Snowman Tonic.csv
# ✓ Soft Wood Log.csv
# ✓ Soft Wood Plank.csv
# ✓ Spicier Flank Steak.csv
# ✓ Spicy Pumpkin Cookie.csv
# ✓ Spool of Jute Thread.csv
# ✓ Spool of Linen Thread.csv
# ✓ Spool of Wool Thread.csv
# ✓ Spring Roll.csv
# ✓ Steamed Red Dumpling.csv
# ✓ Stick of Butter.csv
# ✓ Strawberry Ghost.csv
# ✓ Strawberry Tart.csv
# ✓ Strawberry.csv
# ✓ Stretched Rawhide Leather Square.csv
# ✓ Super Loot Bag.csv
# ✓ Superior Ballista Blueprints.csv
# ✓ Superior Trebuchet Blueprints.csv
# ✓ Supplies.csv
# ✓ Sweet Bean Bun.csv
# ✓ Talisman of Mending.csv
# ✓ Tarragon Leaves.csv
# ✓ Thermocatalytic Reagent.csv
# ✓ Thick Leather Section.csv
# ✓ Thin Leather Section.csv
# ✓ Thyme Leaf.csv
# ✓ Tiny Snowflake.csv
# ✓ Totem.csv
# ✓ Toxic Spore Skin.csv
# ✓ Trick-or-Treat Bag.csv
# ✓ Tropical Peppermint Cake.csv
# ✓ Tuning Icicle.csv
# ✓ Turnip.csv
# ✓ Ugly Wool Hat.csv
# ✓ Ugly Wool Sock.csv
# ✓ Ugly Wool Sweater.csv
# ✓ Unidentified Dye.csv
# ✓ Unique Snowflake.csv
# ✓ Unstable Hide.csv
# ✓ Unstable Rag.csv
# ✓ Vanilla Bean.csv
# ✓ Vial of Maize Balm.csv
# ✓ Vial of Potent Blood.csv
# ✓ Vial of Powerful Blood.csv
# ✓ Vial of Thin Blood.csv
# ✓ Vicious Claw.csv
# ✓ Walnut.csv
# ✓ Watchwork Sprocket.csv
# ✓ Wintersday Gift.csv
# ✓ Wool Patch.csv
# ✓ Wool Scrap.csv
# ✓ Yam.csv
# ✓ Zucchini.csv
#
# ==================================================
# Download Summary:
#   Downloaded: 280/280
#   Skipped: 0/280
#   Failed: 0/280
#   Location: /models/data/workdir_lusis/raw
#   Source: ost-s3/datasources/gw2/raw/1764510842
# ==================================================

# %%
# Be a bit careful, this loads the entire directory into memory!
from tqdm import tqdm
data = []
csv_files = [f for f in os.path.join(workdir_raw, 'data') if f.endswith('.csv')]

for csv_file in tqdm(csv_files, desc="Loading CSV files"):
    file_path = os.path.join(workdir_raw, csv_file)
    df = pd.read_csv(file_path, delimiter=';')
    data.append(df)

print(f"\nTotal DataFrames loaded: {len(data)}")

# Set timestamp as index and drop fetched_at and created_at columns
for i in tqdm(range(len(data)), desc="Processing timestamps"):
    data[i] = data[i].drop(columns=['fetched_at', 'created_at', 'id', 'whitelisted'])
    data[i] = data[i].set_index('timestamp')

data[1].head()
# Out:
# Loading CSV files: 100%|██████████| 280/280 [00:07<00:00, 36.78it/s]
# Total DataFrames loaded: 280
# Processing timestamps: 100%|██████████| 280/280 [00:00<00:00, 1053.59it/s]
#                                   item_id  buy_quantity  buy_unit_price  \
# timestamp
# 2025-07-29 14:45:28.488814+00:00   102255         25448             186
# 2025-07-29 14:50:27.564034+00:00   102255         25414             186
# 2025-07-29 14:55:28.456291+00:00   102255         25387             186
# 2025-07-29 15:00:37.541989+00:00   102255         25741             187
# 2025-07-29 15:05:28.851131+00:00   102255         25739             187
#
#                                   sell_quantity  sell_unit_price
# timestamp
# 2025-07-29 14:45:28.488814+00:00          89414              190
# 2025-07-29 14:50:27.564034+00:00          89640              190
# 2025-07-29 14:55:28.456291+00:00          89640              190
# 2025-07-29 15:00:37.541989+00:00          89499              190
# 2025-07-29 15:05:28.851131+00:00          89723              190

# %%
# Calculate simple returns for each DataFrame
for i in tqdm(range(len(data)), desc="Calculating simple returns"):
    # Save item_id column before calculating returns
    item_id_col = data[i]['item_id']

    # Calculate percentage change (simple returns) for all columns except item_id
    data[i] = data[i].drop(columns=['item_id']).pct_change()

    # Add item_id column back
    data[i]['item_id'] = item_id_col

    # Drop the first row which will be NaN after pct_change
    data[i] = data[i].dropna()

print(f"\nReturns calculated for {len(data)} DataFrames")
data[1].head()
# Out:
# Calculating simple returns: 100%|██████████| 280/280 [00:00<00:00, 551.80it/s]
# Returns calculated for 280 DataFrames
#                                   buy_quantity  buy_unit_price  sell_quantity  \
# timestamp
# 2025-07-29 14:50:27.564034+00:00     -0.001336        0.000000       0.002528
# 2025-07-29 14:55:28.456291+00:00     -0.001062        0.000000       0.000000
# 2025-07-29 15:00:37.541989+00:00      0.013944        0.005376      -0.001573
# 2025-07-29 15:05:28.851131+00:00     -0.000078        0.000000       0.002503
# 2025-07-29 15:10:30.104458+00:00     -0.006527        0.000000      -0.001148
#
#                                   sell_unit_price  item_id
# timestamp
# 2025-07-29 14:50:27.564034+00:00              0.0   102255
# 2025-07-29 14:55:28.456291+00:00              0.0   102255
# 2025-07-29 15:00:37.541989+00:00              0.0   102255
# 2025-07-29 15:05:28.851131+00:00              0.0   102255
# 2025-07-29 15:10:30.104458+00:00              0.0   102255

# %%
import matplotlib.pyplot as plt
# Matplotlib is faster than seaborn for simple line plots
df_to_plot = data[1].drop(columns=['item_id'])

# Plot buy columns together
buy_cols = [col for col in df_to_plot.columns if col.startswith('buy_')]
if buy_cols:
    plt.figure(figsize=(12, 6))
    df_to_plot[buy_cols].plot(alpha=0.7, ax=plt.gca())
    plt.title('Buy Metrics')
    plt.xlabel('Timestamp')
    plt.ylabel('Returns')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# Plot sell columns together
sell_cols = [col for col in df_to_plot.columns if col.startswith('sell_')]
if sell_cols:
    plt.figure(figsize=(12, 6))
    df_to_plot[sell_cols].plot(alpha=0.7, ax=plt.gca())
    plt.title('Sell Metrics')
    plt.xlabel('Timestamp')
    plt.ylabel('Returns')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Run Dickey fuller on the augmented data set.

# %%
from statsmodels.tsa.stattools import adfuller
import pandas as pd
import numpy as np

def adf_test(series, name=''):
     # Replace inf with NaN and drop all NaN values
    clean_series = series.replace([np.inf, -np.inf], np.nan).dropna()

    if len(clean_series) < 12:  # ADF test needs sufficient observations
        return {
            'Series': name,
            'ADF Statistic': np.nan,
            'p-value': np.nan,
            'Lags Used': np.nan,
            'Observations': len(clean_series),
            'Critical Value (1%)': np.nan,
            'Critical Value (5%)': np.nan,
            'Critical Value (10%)': np.nan,
            'Stationary (5%)': 'Insufficient Data'
        }

    result = adfuller(clean_series, autolag='AIC')
    return {
        'Series': name,
        'ADF Statistic': result[0],
        'p-value': result[1],
        'Lags Used': result[2],
        'Observations': result[3],
        'Critical Value (1%)': result[4]['1%'],
        'Critical Value (5%)': result[4]['5%'],
        'Critical Value (10%)': result[4]['10%'],
        'Stationary (5%)': 'Yes' if result[1] < 0.05 else 'No'
    }


# Run ADF test for all items
adf_results = []

for idx, df in enumerate(tqdm(data, desc="Running ADF tests")):
    item_id = df['item_id'].iloc[0] if 'item_id' in df.columns else idx

    numeric_cols = df.select_dtypes(include=['number']).columns

    for col in numeric_cols:
        if col != 'item_id':
            result = adf_test(df[col], name=f"Item {item_id} - {col}")
            adf_results.append(result)

# Convert results to DataFrame for easier viewing
adf_df = pd.DataFrame(adf_results)
# Out:
# Running ADF tests: 100%|██████████| 280/280 [19:59<00:00,  4.28s/it]

# %%
# Save modified files

# %%
# Visualize ADF test results
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set_style("whitegrid")

fig, ax = plt.subplots(figsize=(10, 6))

stationary_counts = adf_df['Stationary (5%)'].value_counts()
colors = ['#2ecc71' if x == 'Yes' else '#e74c3c' for x in stationary_counts.index]
stationary_counts.plot(kind='bar', ax=ax, color=colors)
ax.set_title('Stationarity Distribution (5% significance)', fontsize=14, fontweight='bold')
ax.set_xlabel('Stationary')
ax.set_ylabel('Count')
ax.tick_params(rotation=0)
for i, v in enumerate(stationary_counts.values):
    ax.text(i, v + 0.5, str(v), ha='center', va='bottom', fontweight='bold')

plt.tight_layout()
plt.savefig(os.path.join(workdir_modified,"adf_results", 'adf_stationarity_distribution.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
# 2. P-value distribution
fig, ax = plt.subplots(figsize=(10, 6))

ax.hist(adf_df['p-value'], bins=50, color='#3498db', edgecolor='black', alpha=0.7)
ax.axvline(x=0.05, color='red', linestyle='--', linewidth=2, label='5% significance level')
ax.set_title('Distribution of P-values', fontsize=14, fontweight='bold')
ax.set_xlabel('P-value')
ax.set_ylabel('Frequency')
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(workdir_modified,"adf_results", 'adf_pvalue_distribution.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
# 3. ADF Statistic vs Critical Value (5%)
fig, ax = plt.subplots(figsize=(10, 6))

ax.scatter(adf_df['ADF Statistic'], adf_df['Critical Value (5%)'],
           c=adf_df['Stationary (5%)'].map({'Yes': '#2ecc71', 'No': '#e74c3c'}),
           alpha=0.6, s=50)
ax.plot([adf_df['ADF Statistic'].min(), adf_df['ADF Statistic'].max()],
         [adf_df['ADF Statistic'].min(), adf_df['ADF Statistic'].max()],
         'k--', linewidth=2, label='Equal line')
ax.set_title('ADF Statistic vs Critical Value (5%)', fontsize=14, fontweight='bold')
ax.set_xlabel('ADF Statistic')
ax.set_ylabel('Critical Value (5%)')
ax.legend(['Equal line', 'Stationary', 'Non-stationary'])
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(workdir_modified,"adf_results", 'adf_statistic_vs_critical.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
# 4. Stationarity by series type
fig, ax = plt.subplots(figsize=(10, 6))

series_types = adf_df['Series'].str.extract(r'- (.+)$')[0]
stationarity_by_type = pd.crosstab(series_types, adf_df['Stationary (5%)'])
stationarity_by_type.plot(kind='bar', ax=ax, color=['#e74c3c', '#2ecc71'], stacked=False)
ax.set_title('Stationarity by Series Type', fontsize=14, fontweight='bold')
ax.set_xlabel('Series Type')
ax.set_ylabel('Count')
ax.tick_params(rotation=45)
ax.legend(title='Stationary')

plt.tight_layout()
plt.savefig(os.path.join(workdir_modified,"adf_results", 'adf_stationarity_by_type.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
# Summary Statistics
print("=" * 80)
print("ADF TEST SUMMARY STATISTICS")
print("=" * 80)
print(f"\nTotal series tested: {len(adf_df)}")
print(f"Stationary series (5% level): {(adf_df['Stationary (5%)'] == 'Yes').sum()} ({(adf_df['Stationary (5%)'] == 'Yes').sum() / len(adf_df) * 100:.2f}%)")
print(f"Non-stationary series (5% level): {(adf_df['Stationary (5%)'] == 'No').sum()} ({(adf_df['Stationary (5%)'] == 'No').sum() / len(adf_df) * 100:.2f}%)")

print("\n" + "-" * 80)
print("P-VALUE STATISTICS")
print("-" * 80)
print(f"Mean p-value: {adf_df['p-value'].mean():.4f}")
print(f"Median p-value: {adf_df['p-value'].median():.4f}")
print(f"Min p-value: {adf_df['p-value'].min():.4f}")
print(f"Max p-value: {adf_df['p-value'].max():.4f}")
# Out:
# ================================================================================
# ADF TEST SUMMARY STATISTICS
# ================================================================================
#
# Total series tested: 1120
# Stationary series (5% level): 1120 (100.00%)
# Non-stationary series (5% level): 0 (0.00%)
#
# --------------------------------------------------------------------------------
# P-VALUE STATISTICS
# --------------------------------------------------------------------------------
# Mean p-value: 0.0000
# Median p-value: 0.0000
# Min p-value: 0.0000
# Max p-value: 0.0000

# %%
# Stationarity breakdown by series type
series_types = adf_df['Series'].str.extract(r'- (.+)$')[0]

print("-" * 80)
print("STATIONARITY BY SERIES TYPE")
print("-" * 80)
series_types_summary = pd.crosstab(series_types, adf_df['Stationary (5%)'], margins=True)
print(series_types_summary)
# Out:
# --------------------------------------------------------------------------------
# STATIONARITY BY SERIES TYPE
# --------------------------------------------------------------------------------
# Stationary (5%)   Yes   All
# 0
# buy_quantity      280   280
# buy_unit_price    280   280
# sell_quantity     280   280
# sell_unit_price   280   280
# All              1120  1120

# %%
# Top and bottom series
print("-" * 80)
print("TOP 10 MOST STATIONARY SERIES (lowest p-values)")
print("-" * 80)
print(adf_df.nsmallest(10, 'p-value')[['Series', 'ADF Statistic', 'p-value', 'Stationary (5%)']].to_string(index=False))

print("\n" + "-" * 80)
print("TOP 10 LEAST STATIONARY SERIES (highest p-values)")
print("-" * 80)
print(adf_df.nlargest(10, 'p-value')[['Series', 'ADF Statistic', 'p-value', 'Stationary (5%)']].to_string(index=False))
# Out:
# --------------------------------------------------------------------------------
# TOP 10 MOST STATIONARY SERIES (lowest p-values)
# --------------------------------------------------------------------------------
#                        Series  ADF Statistic  p-value Stationary (5%)
#     Item 19703 - buy_quantity     -22.262482      0.0             Yes
#   Item 19703 - buy_unit_price     -32.618008      0.0             Yes
#    Item 19703 - sell_quantity     -21.699888      0.0             Yes
#  Item 19703 - sell_unit_price     -32.848812      0.0             Yes
#    Item 102255 - buy_quantity    -174.276359      0.0             Yes
#  Item 102255 - buy_unit_price     -30.658591      0.0             Yes
#   Item 102255 - sell_quantity     -32.744961      0.0             Yes
# Item 102255 - sell_unit_price     -35.641435      0.0             Yes
#     Item 75270 - buy_quantity    -175.337921      0.0             Yes
#   Item 75270 - buy_unit_price    -175.806809      0.0             Yes
#
# --------------------------------------------------------------------------------
# TOP 10 LEAST STATIONARY SERIES (highest p-values)
# --------------------------------------------------------------------------------
#                       Series  ADF Statistic      p-value Stationary (5%)
#    Item 38136 - buy_quantity     -10.994047 6.943084e-20             Yes
#  Item 38136 - buy_unit_price     -10.994096 6.941210e-20             Yes
#   Item 38136 - sell_quantity     -10.995531 6.886688e-20             Yes
# Item 38136 - sell_unit_price     -11.224281 1.978252e-20             Yes
#    Item 68647 - buy_quantity     -11.424368 6.751822e-21             Yes
#   Item 68647 - sell_quantity     -11.454607 5.747276e-21             Yes
#  Item 68647 - buy_unit_price     -11.460192 5.579013e-21             Yes
# Item 68647 - sell_unit_price     -11.490938 4.738297e-21             Yes
#   Item 43773 - sell_quantity     -14.973718 1.189751e-27             Yes
#    Item 38449 - buy_quantity     -18.145204 2.484554e-30             Yes

# %%
import os

# Save to CSV
output_path = os.path.join(workdir_modified,"adf_results", 'adf_test_results.csv')
adf_df.to_csv(output_path, index=False)
print(f"ADF test results saved to: {output_path}")

# Optional: Save a summary report
summary_path = os.path.join(workdir_modified,"adf_results", 'adf_summary.txt')
series_types = adf_df['Series'].str.extract(r'- (.+)$')[0]

with open(summary_path, 'w') as f:
    f.write("=" * 80 + "\n")
    f.write("ADF TEST SUMMARY REPORT\n")
    f.write("=" * 80 + "\n\n")
    f.write(f"Total series tested: {len(adf_df)}\n")
    f.write(
        f"Stationary series (5% level): {(adf_df['Stationary (5%)'] == 'Yes').sum()} ({(adf_df['Stationary (5%)'] == 'Yes').sum() / len(adf_df) * 100:.2f}%)\n")
    f.write(
        f"Non-stationary series (5% level): {(adf_df['Stationary (5%)'] == 'No').sum()} ({(adf_df['Stationary (5%)'] == 'No').sum() / len(adf_df) * 100:.2f}%)\n\n")

    f.write("-" * 80 + "\n")
    f.write("P-VALUE STATISTICS\n")
    f.write("-" * 80 + "\n")
    f.write(f"Mean p-value: {adf_df['p-value'].mean():.4f}\n")
    f.write(f"Median p-value: {adf_df['p-value'].median():.4f}\n")
    f.write(f"Min p-value: {adf_df['p-value'].min():.4f}\n")
    f.write(f"Max p-value: {adf_df['p-value'].max():.4f}\n\n")

    f.write("-" * 80 + "\n")
    f.write("STATIONARITY BY SERIES TYPE\n")
    f.write("-" * 80 + "\n")
    series_types_summary = pd.crosstab(series_types, adf_df['Stationary (5%)'], margins=True)
    f.write(series_types_summary.to_string())
    f.write("\n")

print(f"Summary report saved to: {summary_path}")
# Out:
# ADF test results saved to: /models/data/workdir_lusis/modified/adf_test_results.csv
# Summary report saved to: /models/data/workdir_lusis/modified/adf_summary.txt
