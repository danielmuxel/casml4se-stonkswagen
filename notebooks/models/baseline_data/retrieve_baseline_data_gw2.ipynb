# %%
# %load_ext dotenv
# %reload_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
gw2tp_items= {
    77750: "Lucky Draketail",
    19976: "Mystic Coin",
    82678: "Pulsing Brandspark",
    19700: "Mithril Ore",
    36041: "Piece of Candy Corn",
    19703: "Silver Ore",
    82991: "Bag of Coffee Beans",
    49424: "+1 Agony Infusion",
    19698: "Gold Ore",
    19729: "Thick Leather Section",
}

# %%
import os
os.getcwd()
os.getcwdb()
# Out:
# b'/home/lukas/Documents/Github/casml4se-stonkswagen/notebooks/models/baseline_data'

# %%
from datetime import datetime
from gw2ml.data.retriever import DataRetriever

#directory in project root.
datapath = "data/raw/"
# Create retriever
retriever = DataRetriever()
for key,value in gw2tp_items.items():
    df = retriever.get_data(
        symbol=str(key),
        source="DAMU",
        start_time=datetime(2025, 5, 1),
        end_time=datetime(2025, 10, 20),
        interval="15m", # does not matter for damu
    )
    df.to_csv(f"{datapath}/{value}.csv", index=False, sep=";")
    print(f"Saved {df.count()} for {value}")
# Out:
# Fetching 77750 from DAMU (raw)...
# Loading from cache: 77750_raw_20250501_20251020.csv
# Saved id                 21866
# item_id            21866
# whitelisted        21866
# buy_quantity       21866
# buy_unit_price     21866
# sell_quantity      21866
# sell_unit_price    21866
# fetched_at         21866
# created_at         21866
# timestamp          21866
# dtype: int64 for Lucky Draketail
# Fetching 19976 from DAMU (raw)...
# Loading from cache: 19976_raw_20250501_20251020.csv
# Saved id                 21867
# item_id            21867
# whitelisted        21867
# buy_quantity       21867
# buy_unit_price     21867
# sell_quantity      21867
# sell_unit_price    21867
# fetched_at         21867
# created_at         21867
# timestamp          21867
# dtype: int64 for Mystic Coin
# Fetching 82678 from DAMU (raw)...
# Loading from cache: 82678_raw_20250501_20251020.csv
# Saved id                 21863
# item_id            21863
# whitelisted        21863
# buy_quantity       21863
# buy_unit_price     21863
# sell_quantity      21863
# sell_unit_price    21863
# fetched_at         21863
# created_at         21863
# timestamp          21863
# dtype: int64 for Pulsing Brandspark
# Fetching 19700 from DAMU (raw)...
# Loading from cache: 19700_raw_20250501_20251020.csv
# Saved id                 21861
# item_id            21861
# whitelisted        21861
# buy_quantity       21861
# buy_unit_price     21861
# sell_quantity      21861
# sell_unit_price    21861
# fetched_at         21861
# created_at         21861
# timestamp          21861
# dtype: int64 for Mithril Ore
# Fetching 36041 from DAMU (raw)...
# Loading from cache: 36041_raw_20250501_20251020.csv
# Saved id                 21873
# item_id            21873
# whitelisted        21873
# buy_quantity       21873
# buy_unit_price     21873
# sell_quantity      21873
# sell_unit_price    21873
# fetched_at         21873
# created_at         21873
# timestamp          21873
# dtype: int64 for Piece of Candy Corn
# Fetching 19703 from DAMU (raw)...
# Loading from cache: 19703_raw_20250501_20251020.csv
# Saved id                 21861
# item_id            21861
# whitelisted        21861
# buy_quantity       21861
# buy_unit_price     21861
# sell_quantity      21861
# sell_unit_price    21861
# fetched_at         21861
# created_at         21861
# timestamp          21861
# dtype: int64 for Silver Ore
# Fetching 82991 from DAMU (raw)...
# Loading from cache: 82991_raw_20250501_20251020.csv
# Saved id                 21863
# item_id            21863
# whitelisted        21863
# buy_quantity       21863
# buy_unit_price     21863
# sell_quantity      21863
# sell_unit_price    21863
# fetched_at         21863
# created_at         21863
# timestamp          21863
# dtype: int64 for Bag of Coffee Beans
# Fetching 49424 from DAMU (raw)...
# Loading from cache: 49424_raw_20250501_20251020.csv
# Saved id                 21859
# item_id            21859
# whitelisted        21859
# buy_quantity       21859
# buy_unit_price     21859
# sell_quantity      21859
# sell_unit_price    21859
# fetched_at         21859
# created_at         21859
# timestamp          21859
# dtype: int64 for +1 Agony Infusion
# Fetching 19698 from DAMU (raw)...
# Loading from cache: 19698_raw_20250501_20251020.csv
# Saved id                 21861
# item_id            21861
# whitelisted        21861
# buy_quantity       21861
# buy_unit_price     21861
# sell_quantity      21861
# sell_unit_price    21861
# fetched_at         21861
# created_at         21861
# timestamp          21861
# dtype: int64 for Gold Ore
# Fetching 19729 from DAMU (raw)...
# Loading from cache: 19729_raw_20250501_20251020.csv
# Saved id                 21861
# item_id            21861
# whitelisted        21861
# buy_quantity       21861
# buy_unit_price     21861
# sell_quantity      21861
# sell_unit_price    21861
# fetched_at         21861
# created_at         21861
# timestamp          21861
# dtype: int64 for Thick Leather Section

# %%
from gw2ml.data.s3_sync import upload_folder_to_s3
import time

# Set up parameters
local_folder = datapath
unix_timestamp = int(time.time())
s3_folder_prefix = f'datasources/gw2/raw/{unix_timestamp}/' # folder on s3

# Call the function
upload_folder_to_s3(
    local_folder=local_folder,
    s3_folder_prefix=s3_folder_prefix,
    unix_timestamp=unix_timestamp,
    bucket_name="ost-s3"  # optional, defaults to "ost-s3"
)
# Out:
# Found 10 files to upload
# Unix timestamp: 1763495310
# Target: ost-s3/datasources/gw2/raw/1763495310/
#
# ✓ Pulsing Brandspark.csv
# ✓ Thick Leather Section.csv
# ✓ Mithril Ore.csv
# ✓ Silver Ore.csv
# ✓ Lucky Draketail.csv
# ✓ Bag of Coffee Beans.csv
# ✓ Piece of Candy Corn.csv
# ✓ +1 Agony Infusion.csv
# ✓ Mystic Coin.csv
# ✓ Gold Ore.csv
#
# ==================================================
# Upload Summary:
#   Uploaded: 10/10
#   Failed: 0/10
#   Location: ost-s3/datasources/gw2/raw/1763495310/
#   Timestamp: 1763495310 (2025-11-18 20:48:30)
# ==================================================
