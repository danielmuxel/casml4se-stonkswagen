# %%
# %load_ext dotenv
# %reload_ext dotenv
# %dotenv

# %%
cryptos= {
    "BTC/USDT": "bitcoin",
    "ETH/USDT": "ethereum",
    "DOGE/USDT": "dogecoin",
    "LTC/USDT": "litecoin",
}

# %%
import os
os.getcwd()
# Out:
# '/home/lukas/Documents/Github/casml4se-stonkswagen/notebooks/models/baseline_data'

# %%
from datetime import datetime
from gw2ml.data.retriever import DataRetriever

import os

datapath = os.path.join(os.getenv('DATA_PATH'), 'cryptoraw')
os.makedirs(datapath, exist_ok=True)

# Create retriever
retriever = DataRetriever()
for key,value in cryptos.items():
    df = retriever.get_data(
        symbol=str(key),
        source="BINANCE",
        start_time=datetime(2025, 10, 1),
        end_time=datetime(2025, 11, 17),
        interval="5m",
    )
    df.to_csv(f"{datapath}/{value}.csv", index=False, sep=";")
    print(f"Saved {df.count()} for {value}")
# Out:
# Fetching BTC/USDT from BINANCE (5m)...
# Saved to /home/lukas/Documents/Github/casml4se-stonkswagen/src/data/cache/BTC_USDT_5m_20251001_20251117.csv
# Saved timestamp    13549
# open         13549
# high         13549
# low          13549
# close        13549
# volume       13549
# dtype: int64 for bitcoin
# Fetching ETH/USDT from BINANCE (5m)...
# Saved to /home/lukas/Documents/Github/casml4se-stonkswagen/src/data/cache/ETH_USDT_5m_20251001_20251117.csv
# Saved timestamp    13549
# open         13549
# high         13549
# low          13549
# close        13549
# volume       13549
# dtype: int64 for ethereum
# Fetching DOGE/USDT from BINANCE (5m)...
# Saved to /home/lukas/Documents/Github/casml4se-stonkswagen/src/data/cache/DOGE_USDT_5m_20251001_20251117.csv
# Saved timestamp    13549
# open         13549
# high         13549
# low          13549
# close        13549
# volume       13549
# dtype: int64 for dogecoin
# Fetching LTC/USDT from BINANCE (5m)...
# Saved to /home/lukas/Documents/Github/casml4se-stonkswagen/src/data/cache/LTC_USDT_5m_20251001_20251117.csv
# Saved timestamp    13549
# open         13549
# high         13549
# low          13549
# close        13549
# volume       13549
# dtype: int64 for litecoin

# %%
from gw2ml.data.s3_sync import upload_folder_to_s3
import time

# Set up parameters
local_folder = datapath
unix_timestamp = int(time.time())
s3_folder_prefix = f'datasources/crypto/raw/{unix_timestamp}/' # folder on s3

# Call the function
upload_folder_to_s3(
    local_folder=local_folder,
    s3_folder_prefix=s3_folder_prefix,
    unix_timestamp=unix_timestamp,
    bucket_name="ost-s3"  # optional, defaults to "ost-s3"
)
# Out:
# Found 4 files to upload
# Unix timestamp: 1763488125
# Target: ost-s3/datasources/crypto/raw/1763488125/
#
# ✓ litecoin.csv
# ✓ ethereum.csv
# ✓ bitcoin.csv
# ✓ dogecoin.csv
#
# ==================================================
# Upload Summary:
#   Uploaded: 4/4
#   Failed: 0/4
#   Location: ost-s3/datasources/crypto/raw/1763488125/
#   Timestamp: 1763488125 (2025-11-18 18:48:45)
# ==================================================
